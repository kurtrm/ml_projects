# %%
zips = [x for x in range(98001, 98200)]

# %%
zips.remove(98012)
zips.remove(98016)
zips.remove(98017)
zips.remove(98018)
zips.remove(98020)
zips.remove(98021)
zips.remove(98026)
zips.remove(98036)
zips.remove(98037)
zips.remove(98043)
zips.remove(98044)
zips.remove(98046)
zips.remove(98047)
zips.remove(98049)
zips.remove(98054)
zips.remove(98060)
zips.remove(98061)
zips.remove(98066)
zips.remove(98067)
zips.remove(98068)
zips.remove(98069)
zips.remove(98076)
zips.remove(98078)
zips.remove(98079)
zips.remove(98080)
zips.remove(98081)
zips.remove(98082)
zips.remove(98084)
zips.remove(98085)
zips.remove(98086)
zips.remove(98087)
zips.remove(98088)
zips.remove(98090)
zips.remove(98091)
zips.remove(98094)
zips.remove(98095)
zips.remove(98096)
zips.remove(98097)
zips.remove(98098)
zips.remove(98099)
zips.remove(98100)
zips.remove(98110)
zips.remove(98120)
zips.remove(98123)
zips.remove(98128)
zips.remove(98130)
zips.remove(98132)
zips.remove(98135)
zips.remove(98137)
zips.remove(98140)
zips.remove(98142)
zips.remove(98143)
zips.remove(98147)
zips.remove(98149)
zips.remove(98150)
zips.remove(98151)
zips.remove(98152)
zips.remove(98153)
zips.remove(98156)
zips.remove(98157)
zips.remove(98159)
zips.remove(98162)
zips.remove(98163)
zips.remove(98167)
zips.remove(98169)
zips.remove(98171)
zips.remove(98172)
zips.remove(98173)
zips.remove(98176)
zips.remove(98179)
zips.remove(98180)
zips.remove(98182)
zips.remove(98183)
zips.remove(98184)
zips.remove(98186)
zips.remove(98187)
zips.remove(98189)
zips.remove(98192)
zips.remove(98193)
zips.remove(98196)
zips.remove(98197)

# %%
zips.append(98224)
zips.append(98288)
zips
# Out:
# [98001,
#  98002,
#  98003,
#  98004,
#  98005,
#  98006,
#  98007,
#  98008,
#  98009,
#  98010,
#  98011,
#  98013,
#  98014,
#  98015,
#  98019,
#  98022,
#  98023,
#  98024,
#  98025,
#  98027,
#  98028,
#  98029,
#  98030,
#  98031,
#  98032,
#  98033,
#  98034,
#  98035,
#  98038,
#  98039,
#  98040,
#  98041,
#  98042,
#  98045,
#  98048,
#  98050,
#  98051,
#  98052,
#  98053,
#  98055,
#  98056,
#  98057,
#  98058,
#  98059,
#  98062,
#  98063,
#  98064,
#  98065,
#  98070,
#  98071,
#  98072,
#  98073,
#  98074,
#  98075,
#  98077,
#  98083,
#  98089,
#  98092,
#  98093,
#  98101,
#  98102,
#  98103,
#  98104,
#  98105,
#  98106,
#  98107,
#  98108,
#  98109,
#  98111,
#  98112,
#  98113,
#  98114,
#  98115,
#  98116,
#  98117,
#  98118,
#  98119,
#  98121,
#  98122,
#  98124,
#  98125,
#  98126,
#  98127,
#  98129,
#  98131,
#  98133,
#  98134,
#  98136,
#  98138,
#  98139,
#  98141,
#  98144,
#  98145,
#  98146,
#  98148,
#  98154,
#  98155,
#  98158,
#  98160,
#  98161,
# ...

# %%
import pickle

pickle.dump(zips, open("zips.p", "wb"))
